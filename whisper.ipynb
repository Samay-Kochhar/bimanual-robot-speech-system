# %%
# !pip install faster-whisper

from faster_whisper import WhisperModel
import time
# Out:
# Requirement already satisfied: faster-whisper in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (1.2.1)
# Collecting ctranslate2<5,>=4.0 (from faster-whisper)
#   Obtaining dependency information for ctranslate2<5,>=4.0 from https://files.pythonhosted.org/packages/85/21/b263fcf8bfd2454590255f4e7d2a2e6d80701960a449e8fd0745b706f6a5/ctranslate2-4.6.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached ctranslate2-4.6.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.21 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from faster-whisper) (1.1.5)
# Requirement already satisfied: tokenizers<1,>=0.13 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from faster-whisper) (0.13.2)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from faster-whisper) (1.23.2)
# Requirement already satisfied: av>=11 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from faster-whisper) (16.0.1)
# Requirement already satisfied: tqdm in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from faster-whisper) (4.65.0)
# Requirement already satisfied: setuptools in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from ctranslate2<5,>=4.0->faster-whisper) (68.0.0)
# Requirement already satisfied: numpy in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from ctranslate2<5,>=4.0->faster-whisper) (2.3.4)
# Requirement already satisfied: pyyaml<7,>=5.3 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0)
# Requirement already satisfied: filelock in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21->faster-whisper) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21->faster-whisper) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21->faster-whisper) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21->faster-whisper) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21->faster-whisper) (25.0)
# Requirement already satisfied: shellingham in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21->faster-whisper) (1.5.4)
# Requirement already satisfied: typer-slim in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21->faster-whisper) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21->faster-whisper) (4.7.1)
# Requirement already satisfied: coloredlogs in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.9.23)
# Requirement already satisfied: protobuf in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (6.33.1)
# Requirement already satisfied: sympy in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.11.1)
# Requirement already satisfied: anyio in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (3.5.0)
# Requirement already satisfied: certifi in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (1.0.9)
# Requirement already satisfied: idna in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (3.4)
# Requirement already satisfied: h11>=0.16 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (0.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from typer-slim->huggingface-hub>=0.21->faster-whisper) (8.0.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (1.2.0)
# Using cached ctranslate2-4.6.1-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
# Installing collected packages: ctranslate2
# Successfully installed ctranslate2-4.6.1

# %%
pip uninstall -y ctranslate2
# Out:
# Found existing installation: ctranslate2 4.6.1
# Uninstalling ctranslate2-4.6.1:
#   Successfully uninstalled ctranslate2-4.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "ctranslate2[cuda]"
# Out:
# Requirement already satisfied: ctranslate2[cuda] in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (4.6.1)
# WARNING: ctranslate2 4.6.1 does not provide the extra 'cuda'
# Requirement already satisfied: setuptools in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from ctranslate2[cuda]) (68.0.0)
# Requirement already satisfied: numpy in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from ctranslate2[cuda]) (2.3.4)
# Requirement already satisfied: pyyaml<7,>=5.3 in /Users/samaykochhar/anaconda3/lib/python3.11/site-packages (from ctranslate2[cuda]) (6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ctranslate2
print(ctranslate2.get_supported_compute_types("cuda"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 import ctranslate2
# ----> 2 print(ctranslate2.get_supported_compute_types("cuda"))
#
# ValueError: This CTranslate2 package was not compiled with CUDA support

# %%
model = WhisperModel("small", device="cuda", compute_type="float16")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model = WhisperModel("small", device="cuda", compute_type="float16")
#
# File ~/anaconda3/lib/python3.11/site-packages/faster_whisper/transcribe.py:689, in WhisperModel.__init__(self, model_size_or_path, device, device_index, compute_type, cpu_threads, num_workers, download_root, local_files_only, files, revision, use_auth_token, **model_kwargs)
#     680 else:
#     681     model_path = download_model(
#     682         model_size_or_path,
#     683         local_files_only=local_files_only,
#    (...)
#     686         use_auth_token=use_auth_token,
#     687     )
# --> 689 self.model = ctranslate2.models.Whisper(
#     690     model_path,
#     691     device=device,
#     692     device_index=device_index,
#     693     compute_type=compute_type,
#     694     intra_threads=cpu_threads,
#     695     inter_threads=num_workers,
#     696     files=files,
#     697     **model_kwargs,
#     698 )
#     700 tokenizer_file = os.path.join(model_path, "tokenizer.json")
#     701 if tokenizer_bytes:
#
# ValueError: This CTranslate2 package was not compiled with CUDA support
